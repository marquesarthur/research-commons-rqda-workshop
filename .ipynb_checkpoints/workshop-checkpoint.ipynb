# %% [markdown]
# <img style="float: right;" src="figures/research_commons_logo.png">
#
# # WORKSHOP: INTRODUCTION TO R FOR QUALITATIVE DATA ANALYSIS
#
# * Arthur Marques (GAA)
# * Mathurada Jullamon (GAA)
#
#
# ***

# %% [markdown]
# # Learning Goals
#
# <img src="figures/gaa-rqda-goals.jpg">
#
# * Understand the basic commands of R and how to use RStudio environment for qualitative data analisys
#
# * Learn how to load, preprocess, and explore text
#
# * Learn the basic commands for text manipulation
#
# * Learn basic commands for desccriptive statistics regarding codings, categories, etc.
#
# ***

# %% [markdown]
# ## Overview of quantitative research
#
#
# This workshop does not address matters as qualitative research design or how to conduct interviews or participant observation fieldwork.
#
#
#
# <img src="figures/qualcycle.png">
#
# [source](https://vickysteeves.gitlab.io/2018-ndsr-art/research-interview.html)
# ***

# %% [markdown]
# ## Familiarisation & coding
#
# <img src="figures/coding.jpg">
#
# [source](https://vickysteeves.gitlab.io/2018-ndsr-art/analyzing-interview-data.html)
#
# ***

# %% [markdown]
# ## Workshop materials
#
# ### Access the UBC research commons R workshop
#
#
# https://github.com/marquesarthur/research-commons-rqda-workshop
#
#
# ***

# %% [markdown]
# ### Download the files for this workshop
#
# <img src="figures/download-zip.png">
#
# ***

# %% [markdown]
# ## R environment
#
# ### Open RStudio
#
# <img src="figures/R_environment.png">
#
# ***

# %% [markdown]
# ### Create a new R script
#
# #### File > New file > R Script
#
# <img src="figures/R_Studio.png">
#
# ***

# %% [markdown]
# ### Change your working directory
#
# Set up a folder/path where data are located as a working directory
#
# <img src="figures/working_directory.png">
#
# ***

# %% [markdown]
# ### R packages
#
# R package is a library of prewritten code designed for a particular task or a collection of tasks
#
# <img src="figures/R_packages.png">
#
# ***

# %% [markdown]
# ### Installing a new package (2 options)
#
#
#
# #### Under Tools -> Packages tab -> Search for “psych” and “dplyr”
#
# <img src="figures/install_packages.png">
#
# ***

# %% [markdown]
# #### Using code: install.packages( ) and library( ) functions
#
# ```
# install.packages("tidyverse")
# install.packages("RQDA")
# install.packages("tm")
# install.packages("wordcloud")
# install.packages("topicmodels")
# install.packages("igraph")
# install.packages("ggplot2")
# install.packages("tidytext")
# install.packages("dplyr")
# install.packages("tidyr")
#
# ```
#
# ***

# %% [markdown]
# #### Importing libraries

# %%
library(tidyverse)
library(tm)
library(topicmodels)
library(wordcloud)
library(igraph)
library(ggplot2)
library(stringr)
library(tidytext)
library(dplyr)
library(tidyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: NLP
#
#
# Attaching package: ‘NLP’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     annotate
#
#
# Loading required package: RColorBrewer
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, simplify
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following object is masked from ‘package:tibble’:
#
#     as_data_frame
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %% [markdown]
# #### Tips
#
# **On the editor**
#
# <kbd>CTRL</kbd>+<kbd>enter</kbd> runs the command in the current line (<kbd>cmd</kbd>+<kbd>enter</kbd> on MacOS)
#
# <kbd>CTRL</kbd>+<kbd>w</kbd> closes current tab (<kbd>cmd</kbd>+<kbd>w</kbd> on MacOS)
#
# After typing the first few lines of a command, <kbd>tab</kbd> auto-completes the command
#
# **On the console**
#
# <kbd>↑</kbd> shows the last command (useful to rerun the command of fix errors)
#
# ***

# %% [markdown]
# # RQDA
#
# <img src="figures/gaa-rqda-goals.jpg">
#
# ***

# %% [markdown]
# ### The RQDA environment

# %%
require("RQDA")
# Out:
# Loading required package: RQDA
#
# Loading required package: RSQLite
#
# Loading required package: gWidgetsRGtk2
#
# Loading required package: RGtk2
#
# Loading required package: gWidgets
#
#
# Attaching package: ‘gWidgets’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     id
#
#
# Loading required package: cairoDevice
#
# Loading required package: DBI

# %% [markdown]
# ```RQDA() # launches the coding environment```

# %% [markdown]
# ***
#
# #### Main screen
#
# <img src="figures/rqda-main-screen.png">

# %% [markdown]
# ***
#
# #### Files tab
#
# <img src="figures/rqda-import-files.png">

# %% [markdown]
# #### Our data
#
#
#
# The G20 (or Group of Twenty) is an international forum for the governments and central bank governors from 19 countries and the European Union (EU). Founded in 1999 with the aim to discuss policy pertaining to the promotion of international financial stability, the G20 has expanded its agenda since 2008 and heads of government or heads of state, as well as finance ministers and foreign ministers, have periodically conferred at summits ever since. It seeks to address issues that go beyond the responsibilities of any one organization. [source](https://en.wikipedia.org/wiki/G20)
#
#
# <img style="float: right;" src="figures/g20.jpg" width="20%">
#
#
# Why G20?
#
# * Lack of public available interview data makes the [UN digital library](https://digitallibrary.un.org/search?ln=en&cc=Speeches)  appealing
# * The UN discuss themes that we can relate worldwide (to some extent), e.g., security, employment, climate change, etc
# * The facilitator is not an expert in qualitative data analysis and they picked a topic that they are confortable discussing :)
#
# ***

# %% [markdown]
# ***
#
# #### Open file
#
# <img src="figures/rqda-file-sample.png">

# %% [markdown]
# ***
#
# #### Codes tab
#
# <img src="figures/rqda-codes.png">

# %% [markdown]
# ***
#
# #### Coding a file
#
# <img src="figures/rqda-coding-selection.png">

# %% [markdown]
# ***
#
# #### Coded sentence
#
# <img src="figures/rqda-coded.png">

# %% [markdown]
# ## Exercise: open the G20-2010-obama file and code some of its senteces.
#
# #### Don't spoil the fun. The stick figure is watching you
#
#
# <br><br><br><br>
#
#
# <img src="figures/watch.png" width="30%">

# %% [markdown]
# ***
#
# #### Open the `rqda-sample.rqda` file and check the coded data
#
# This data was coded by one of the GAAs and it might not be acurate or contain the best themes.
#
# Coding is a subjective process that requires time and cycles, so for the purpose of this workshop, the codings and themes in this sample file sufice

# %% [markdown]
# ***
#
# #### At the end, our file will look like this
#
# <img src="figures/rqda-code-highlight.png">
#
# ## Explore the sample project and let's get started with analyzing the G20 transcripts

# %% [markdown]
# ***
# ***
#
# # RQDA commands on RStudio
#
# <img src="figures/gaa-rqda-goals.jpg">

# %% [markdown]
# ***
#
# ### Loading the data from rqda

# %%
openProject("rqda-sample.rqda")

# %% [markdown]
# ***
#
# ### Extracting files and text
#
# Internally, `rqda` stores data in a `SQL` database. To fetch the data, you have to use the `RQDAQuery` function.
#
# In this workshop, we provide code snippets for the most common data that you may need from a `.rqda` project

# %%
transcripts <- data.frame(name = RQDAQuery("SELECT name FROM source"),
                         text = RQDAQuery("SELECT file FROM source"))

file_names <- transcripts$name

data <- data.frame(file=transcripts$name, text=transcripts$file)

# %%
head(data, n=1)
# Out:
#   file
# 1 G20-2010-obama
#   text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 1 Good afternoon, everybody.\nBefore I discuss the G20, I want to briefly comment on the agreement in Iraq that's taken place on the framework for a new government.\nThere’s still challenges to overcome, but all indications are that the government will be representative, inclusive, and reflect the will of the Iraqi people who cast their ballots in the last election.\n\nThis agreement marks another milestone in the history of modern Iraq.\nOnce again, Iraqis are showing their determination to unify Iraq and build its future and that those impulses are far stronger than those who want Iraq to descend into sectarian war and terror.\n\nFor the last several months, the United States has worked closely with our Iraqi partners to promote a broad-based government -- one whose leaders share a commitment to serving all Iraqis as equal citizens.\nNow, Iraq's leaders must finish the job of forming their government so that they can meet the challenges that a diverse coalition will inevitably face.\nAnd going forward, we will support the Iraqi people as they strengthen their democracy, resolve political disputes, resettle those displaced by war, and build ties of commerce and cooperation with the United States, the region and the world.\n\nNow, here in Seoul, once again, we are very grateful to our hosts -- President Lee, and the people of Seoul and South Korea  -- for your extraordinary hospitality.\n\nWe came to Seoul to continue the work that has taken us from London to Pittsburgh to Toronto.\nWe worked together to pull the global economy back from catastrophe.\nTo avoid the old cycles of boom and bust that led to that crisis, we committed ourselves to growth that is balanced and sustained, including financial reform and fiscal responsibility.\n\nThe actions we took were not always easy or popular.\nBut they were necessary.\nAs a result, the global economy is growing again.\nSome economies, especially emerging economies, are experiencing strong economic growth.\nTrade has risen.\nJobs are being created, as in the United States, where we’ve had 10 consecutive months of private sector job growth and created more than one million private sector jobs this year alone.\n\nIn short, we succeeded in putting the global economy back on the path of recovery -- but we also know that the progress has not come nearly fast enough, especially when it comes to my highest priority, which is putting Americans back to work.\n\nNor have we yet achieved the balanced global growth that we need.\nMany advanced economies are growing too slowly and not creating enough jobs.\nSome countries are running large surpluses, others running large deficits.\nPut simply, we risk slipping back into the old imbalances that contributed to the economic crisis in the first place and which threaten global recovery.\n\nSo here in Seoul, the question was whether our nations could work together to keep the global economy growing.\nI know the commentary tends to focus on the inevitable areas of disagreement, but the fact is the 20 major economies gathered here are in broad agreement on the way forward -- an agreement that is based on a framework that was put forward by the United States.\nAnd for the first time, we spelled out the actions that are required -- in four key areas -- to achieve the sustained and balanced growth that we need.\n\nFirst, we agreed to keep focusing on growth.\nAt home, the United States has been doing our part by making historic investments in infrastructure and education, research and clean energy.\nAnd as a consequence, our economy is growing again -– even as we must do more to ensure that that growth is sustained and translates into jobs for our people.\n\nHere at Seoul, we agreed that growth must be balanced.\nCountries with large deficits must work to reduce them, as we are doing in the United States, where we’re on track to cut our deficit in half by 2013, and where I’m prepared to make tough decisions to achieve that goal.\nLikewise, countries with l ...

# %% [markdown]
# ***
#
# ### Creating a dataset with every file and every sentence
#
# #### We will make use of the `strsplit` function.
#
# Internally, every new line in the text is represented as the special character `\n`
#
# We use this knowlege to split the text into multiple sentences.
#
# This might not be optimal if our input files cointain more than one sentence per line.
#
# Making sure that you transcribe your interviews or input files in a format that *facilitates your work later* is highly desirable.

# %%
s <- strsplit(transcripts$file, split = "\n")
sentences <- data.frame(name = rep(transcripts$name, sapply(s, length)), text = unlist(s))
sentences <- sentences %>%
  filter(text != "") %>%
  na.omit()

# %%
head(sentences)
# Out:
#   name
# 1 G20-2010-obama
# 2 G20-2010-obama
# 3 G20-2010-obama
# 4 G20-2010-obama
# 5 G20-2010-obama
# 6 G20-2010-obama
#   text
# 1 Good afternoon, everybody.
# 2 Before I discuss the G20, I want to briefly comment on the agreement in Iraq that's taken place on the framework for a new government.
# 3 There’s still challenges to overcome, but all indications are that the government will be representative, inclusive, and reflect the will of the Iraqi people who cast their ballots in the last election.
# 4 This agreement marks another milestone in the history of modern Iraq.
# 5 Once again, Iraqis are showing their determination to unify Iraq and build its future and that those impulses are far stronger than those who want Iraq to descend into sectarian war and terror.
# 6 For the last several months, the United States has worked closely with our Iraqi partners to promote a broad-based government -- one whose leaders share a commitment to serving all Iraqis as equal citizens.

# %%
tail(sentences)
# Out:
#     name
# 641 G20-2011-nicolas-sarkozy
# 642 G20-2011-nicolas-sarkozy
# 643 G20-2011-nicolas-sarkozy
# 644 G20-2011-nicolas-sarkozy
# 645 G20-2011-nicolas-sarkozy
# 646 G20-2011-nicolas-sarkozy
#     text
# 641 I might add that I was pleased that Barack Obama was receptive to the principle of the financial sector helping resolve the crisis. This doesn’t go as far as a financial transaction tax, but he was receptive to the idea of financial players making a financial contribution to find a way out of the crisis.
# 642 Let me remind you that we started from a situation of absolute deadlock and that the financial transaction tax is now up for debate, and I hope it will actually be implemented in 2012.
# 643 There are still a lot of things to resolve, particularly on allocating the product of the future tax, but it’s very interesting because when you discuss allocating the product of the future tax it’s because you believe the principle of the tax has made so much progress that it’s appropriate to discuss allocating the product of it.
# 644 France believes a large share, yet to be defined – a majority of the total – should go to development.
# 645 Finally, we had a debate on global governance, with a very good report by David Cameron.
# 646 There you are, ladies and gentlemen; I apologize for no doubt talking for too long. I’ll now take your questions.

# %% [markdown]
# # Codes & Categories
#
# <img src="figures/gaa-rqda-goals.jpg">

# %% [markdown]
# ***
#
# ### Loading the codes from rqda

# %%
head(getCodingTable())
# Out:
#   rowid cid fid codename       filename       index1 index2 CodingLength
# 1 1      8  1   foreign policy G20-2010-obama   52    364   312
# 2 2     11  1   terrorism      G20-2010-obama  447    629   182
# 3 3     14  1   democracy      G20-2010-obama  631    837   206
# 4 4     16  1   economy        G20-2010-obama 1492   1745   253
# 5 5     16  1   economy        G20-2010-obama 1747   1962   215
# 6 6      2  1   employment     G20-2010-obama 1980   2166   186

# %%
codings <- getCodingTable()[,4:5]
head(codings)
# Out:
#   codename       filename
# 1 foreign policy G20-2010-obama
# 2 terrorism      G20-2010-obama
# 3 democracy      G20-2010-obama
# 4 economy        G20-2010-obama
# 5 economy        G20-2010-obama
# 6 employment     G20-2010-obama

# %%
categories <- RQDAQuery("SELECT filecat.name AS category, source.name AS filename 
                         FROM treefile, filecat, source 
                         WHERE treefile.catid=filecat.catid
                         AND treefile.fid=source.id AND treefile.status=1")
head(categories)
# Out:
#   category filename
# 1 2011     G20-2011-obama
# 2 2012     G20-2012-obama
# 3 2010     G20-2010-obama
# 4 2013     G20-2013-obama
# 5 2014     G20-2014
# 6 2015     G20-2015

# %% [markdown]
# ***
#
# ### Plotting the extracted codes

# %%
# you don't need to runn these two lines. they are only for resizing the plot to the GAA screen
library(repr) 
options(repr.plot.width=18, repr.plot.height=15)

# %% [markdown]
# Each one of our files has a year. We are interested in plotting the distribution of themes per year.

# %%
# replace filename with year
codings$filename <- str_extract(codings$filename, "[0-9]{4}")

# %%
reorder_size <- function(x) {
  factor(x, levels = names(sort(table(x))))
}

# %% [markdown]
# #### Use the  `ggplot` function to plot the data

# %%
ggplot(data=codings, aes(reorder_size(codename))) + geom_bar(stat="count") + 
  facet_grid(~filename) + coord_flip() + 
  theme(legend.position="bottom", 
        legend.title=element_blank(),
        text=element_text(size=14),
        axis.text.y=element_text(size=20),
        axis.text.x=element_text(size=16),
        axis.title=element_text(size=14)) +
  ylab("Code frequency in data") + xlab("Code")
# Out:
# plot without title

# %% [markdown]
# ***
#
# ### In the plot above, we don't use categories. Let's try a different plot with categories:

# %%
codings <- getCodingTable()[,4:5]
codings <- merge(codings, categories, all.y = TRUE)

# %%
head(codings)
# Out:
#   filename       codename       category
# 1 G20-2010-obama foreign policy obama
# 2 G20-2010-obama foreign policy 2010
# 3 G20-2010-obama foreign policy G20
# 4 G20-2010-obama terrorism      obama
# 5 G20-2010-obama terrorism      2010
# 6 G20-2010-obama terrorism      G20

# %%
ggplot(codings, aes(reorder_size(codename), fill=category)) + geom_bar(stat="count") +
    coord_flip() + 
    theme(legend.position="bottom", 
        legend.title=element_blank(),
        text=element_text(size=14),
        axis.text.y=element_text(size=20),
        axis.text.x=element_text(size=16),
        axis.title=element_text(size=14)) +
    ylab("Code frequency in interviews") + xlab("Code")
# Out:
# plot without title

# %% [markdown]
# Depending on how you organize your categories, this plot may change drastically. For more examples of plots check this [rqda tutorial](https://lucidmanager.org/qualitative-data-science/).

# %% [markdown]
# ## From the coded data, we can infer things suchs as:
#
# 1. As the initial purpose of the G20, economy is still a major theme in any summit
# 1. Climate change is gaining momentum. In early years, it was not a theme open for discussion at all whereas in the past few years, it is being discussed more than economy
# 1. Employment was a theme brought in many of the early year summits. It makes sense as [Europe was in a recession period](https://en.wikipedia.org/wiki/Great_Recession_in_Europe)

# %% [markdown]
# ***
#
# ### Getting the text related to each code element

# %%
coded_text <- RQDAQuery(
    "SELECT coding.cid, source.name AS filename, coding.seltext
     FROM coding, source
     WHERE coding.fid=source.id")

# %%
cdata <- merge(coded_text, getCodingTable()[, c("cid", "codename")], by="cid") %>%
    rename(text=seltext) %>%
    select(codename, filename, text)

# %% [markdown]
# ### Now that we know the coded categories, we can sample quotes related to each theme

# %%
sample <- cdata %>% filter(codename == "climate change")
sample[sample(nrow(sample), 3), ] # this line picks 3 random rows, we could have used head or tail instead
# Out:
#     codename
# 602 climate change
# 151 climate change
# 404 climate change
#     filename
# 602 G20-2014-obama
# 151 G20-2019
# 404 greta-thunberg-un-climate-change-conference-speech-transcript
#     text
# 602 This week, we also took historic steps in the fight against climate change.
# 151 I believe in what has been considered by the IPCC [Intergovernmental Panel on Climate Change] report, the most valid scientific position today, which is that we need to make sure that we do not reach more than 1.5 degrees Celsius of global warming at the end of the century.
# 404 That means that richer countries need to do their fair share and get down to real zero emissions much faster and then help poorer countries do the same, so people in less fortunate parts of the world can raise their living standards.\nThese numbers also don’t include most feedback loops, nonlinear tipping points, or additional warming hidden by toxic air pollution.

# %%
sample <- cdata %>% filter(codename == "economy")

sample[sample(nrow(sample), 3), ] # this line picks 3 random rows, we could have used head or tail instead
# Out:
#      codename filename
# 657  economy  G20-2018
# 1514 economy  G20-2014
# 293  economy  G20-2010-obama
#      text
# 657  \nFailure to act means more disasters and emergencies and air pollution that could cost the global economy as much as US$21 trillion by 2050.\n
# 1514 Some of the largest financial institutions, investors, banks and insurance companies will announce that they will shift more than 200 billion dollars toward building low-carbon economies by 2015.
# 293  Second, we agreed that exchange rates must reflect economic realities.

# %%
sample <- cdata %>% filter(codename == "foreign policy")

sample[sample(nrow(sample), 3), ] # this line picks 3 random rows, we could have used head or tail instead
# Out:
#     codename       filename
# 266 foreign policy G20-2015
# 26  foreign policy G20-2012-obama
# 175 foreign policy G20-2013-obama
#     text
# 266 Paris must send a clear signal to markets that the low-carbon transformation of the global economy is inevitable and beneficial.\n
# 26  So today, the United States and the European Union agreed to take the next step in our work towards the possible launching of negotiations on an agreement to strengthen our already very deep trade and investment partnership.
# 175 So, in the coming days, I’ll continue to consult with my fellow leaders around the world, and I will continue to consult with Congress.\nAnd I will make the best case that I can to the American people, as well as to the international community, for taking necessary and appropriate action.

# %%
sample <- cdata %>% filter(codename == "employment")

sample[sample(nrow(sample), 3), ] # this line picks 3 random rows, we could have used head or tail instead
# Out:
#     codename   filename
# 206 employment G20-2012-obama
# 28  employment G20-2012-obama
# 210 employment G20-2011-obama
#     text
# 206 In the United States, our businesses have created jobs for 27 months in a row -- more than 4 million jobs in all -- and our highest priority continues to be putting people back to work even faster.
# 28  As the world’s largest economy, the best thing the United States can do is to create jobs and growth in the short term, even as we continue to put our fiscal house in order over the long term.
# 210 we agreed to stay focused on jobs and growth with an action plan in which each nation does its part.

# %%
sample <- cdata %>% filter(codename == "security")

sample[sample(nrow(sample), 3), ] # this line picks 3 random rows, we could have used head or tail instead
# Out:
#     codename filename
# 196 security G20-2016
# 215 security G20-2014
# 257 security G20-2013-obama
#     text
# 196 In Sri Lanka, I stressed that ongoing efforts in peacebuilding, reconciliation and post-conflict transformation, including transitional justice, provide an opportunity for this country to emerge from this trauma stronger.
# 215 I urge the world leaders gathered in New York, especially those participating in tomorrow’s Security Council Summit on foreign terrorist fighters, to come together decisively in support of efforts to confront these groups.
# 257 I’ve been encouraged by discussions with my fellow leaders this week; there is a growing recognition that the world cannot stand idly by.\nHere in St. Petersburg, leaders from Europe, Asia, and the Middle East have come together to say that the international norm against the use of chemical weapons must be upheld, and that the Assad regime used these weapons on its own people, and that, as a consequence, there needs to be a strong response.

# %%
sample <- cdata %>% filter(codename == "terrorism")

sample[sample(nrow(sample), 3), ] # this line picks 3 random rows, we could have used head or tail instead
# Out:
#     codename  filename
# 8   terrorism G20-2010-obama
# 116 terrorism G20-2015
# 102 terrorism G20-2014
#     text
# 8    Iraqis are showing their determination to unify Iraq and build its future and that those impulses are far stronger than those who want Iraq to descend into sectarian war and terror.
# 116 Let me start by reiterating my profound condolences to the people of France following the barbaric terrorist attacks in Paris on Friday night.\nMy thoughts are with the families of the victims at this time of grief and loss.
# 102 Confronting terrorist groups operating in Syria requires a multi-facetted approach.\nThis approach should be designed to address the immediate security risks, to stop atrocity crimes and, over the longer term, to eliminate the conditions in which these groups take root.

# %%
sample <- cdata %>% filter(codename == "climate change")

sample[sample(nrow(sample), 3), ] # this line picks 3 random rows, we could have used head or tail instead
# Out:
#     codename       filename
# 86  climate change G20-2014-obama
# 68  climate change G20-2018
# 449 climate change G20-2016
#     text
# 86  So from trade to climate change to the fight against Ebola, this was a strong week for American leadership.
# 68  \nThe social, economic and environmental costs of climate change dwarf the costs of acting now.\n
# 449 The G20 this year is going through a great transformation, moving from a short-term focus on managing global financial challenges to a long-term vision for sustainable development.

# %% [markdown]
# # Word Cloud
#
# <img src="figures/gaa-rqda-goals.jpg">

# %% [markdown]
# ### To build a word cloud, we need to count the amount of times each word (i.e., `term`) appears in each document
#
# ### This is also known as a `document term matrix`, e.g.:
#
# <img src="figures/dtm.png">
#
# [source](https://www.quora.com/What-is-a-term-document-matrix)

# %% [markdown]
# ***
#
# #### We use the `VectorSource` and `Corpus` functions from the text-mining (`tm`) package to build a document term matrix
#
# Notice that there are very common words in some languages. For instance, in `English` words like `a`, `an`, `is`, `'t`, `have`, etc are pretty common and we need to remove them from our corpus. Otherwise, they wold appear as part of the word cloud.
#
# We call these common words `stopwords` and the entire document-term-matrix is built with the following code snippet:

# %%
document_term_matrix <- function(data) {
    text <- Corpus(VectorSource(data))
    text <-  tm_map(text, stripWhitespace)
    text <-  tm_map(text, content_transformer(tolower))
    text <-  tm_map(text, removeWords, stopwords("english"))
    text <-  tm_map(text, removePunctuation)
    text <-  tm_map(text, removeNumbers)
}

# %%
tdm <- document_term_matrix(sentences$text)
# Out:
# Warning message in tm_map.SimpleCorpus(text, stripWhitespace):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, content_transformer(tolower)):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removeWords, stopwords("english")):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removeNumbers):
# “transformation drops documents”

# %% [markdown]
# ***
#
# ### Plotting the word cloud

# %%
# you don't need to runn these two lines. they are only for resizing the plot to the GAA screen
options(repr.plot.width=12, repr.plot.height=8)
set.seed(42)

# %%
wordcloud(tdm, min.freq = 10, max.words = 50, rot.per=0.35, colors = brewer.pal(8, "Blues")[-1:-5])
# Out:
# plot without title

# %%
BigramTokenizer <-
  function(x)
    unlist(lapply(ngrams(words(x), 2), paste, collapse = " "), use.names = FALSE)

tdm <- TermDocumentMatrix(as.charactersentences$text, control = list(tokenize = BigramTokenizer))
inspect(removeSparseTerms(tdm[, 1:10], 0.7))
# Out:
# Error in UseMethod("TermDocumentMatrix", x): no applicable method for 'TermDocumentMatrix' applied to an object of class "character"
# Traceback:
#
# 1. TermDocumentMatrix(as.character(sentences$text), control = list(tokenize = BigramTokenizer))

# %% [markdown]
# # Topic Modeling
#
# <img src="figures/gaa-rqda-goals.jpg">

# %% [markdown]
# A topic model is a type of statistical model for discovering the abstract "topics" that occur in a collection of documents. Topic modeling is a frequently used text-mining tool for discovery of hidden semantic structures in a text body. Intuitively, given that a document is about a particular topic, one would expect particular words to appear in the document more or less frequently: "dog" and "bone" will appear more often in documents about dogs, "cat" and "meow" will appear in documents about cats, and "the" and "is" will appear equally in both. [source](https://en.wikipedia.org/wiki/Topic_model)

# %% [markdown]
# <img src="figures/topic-modeling.gif">
#
# [source](https://aws.amazon.com/blogs/machine-learning/introduction-to-the-amazon-sagemaker-neural-topic-model/)
#
# ***

# %% [markdown]
# We can apply topic modeling both at `the sentence level` or at `the document level`.
#
# Notice that this is methodology that relies on statistics and probability. There are no explicit themes or categories that arise from a topic and you will have to reason whether the topics make sense or not.
#
# Nonetheless, topic modeling is a powerful tool and it might help you analyzing large chunks of text.

# %% [markdown]
# ***
#
# #### Let's apply topic modeling to our G20 data.

# %% [markdown]
# ## Topic modeling at the document level

# %%
text <- document_term_matrix(data$text)
# Out:
# Warning message in tm_map.SimpleCorpus(text, stripWhitespace):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, content_transformer(tolower)):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removeWords, stopwords("english")):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removeNumbers):
# “transformation drops documents”

# %% [markdown]
# #### First, we must define the number of topics

# %%
n_topics = 9
n_top_words = 10

# %% [markdown]
# #### Once again, we make use of the document term matrix

# %%
dtm <- DocumentTermMatrix(text)
dtm <- removeSparseTerms(dtm, 0.99)

# %% [markdown]
# #### Finally, we apply the `LDA` function to extract topics

# %%
ldaOut <- LDA(dtm, k = n_topics)

# %% [markdown]
# #### We can check the top words that make a topic. Using these words, we may assign a label to a topic

# %%
terms(ldaOut, n_top_words)
# Out:
#       Topic 1       Topic 2       Topic 3   Topic 4   Topic 5   Topic 6
#  [1,] tax           will          ’s        will      growth    growth
#  [2,] –             global        made      climate   must      europe
#  [3,] financial     need          capital   change    need      will
#  [4,] ’s            climate       tax       people    states    financial
#  [5,] countries     also          will      emissions united    leaders
#  [6,] transaction   countries     didn’t    just      agreed    states
#  [7,] growth        development   financial now       agreement united
#  [8,] finally       summit        progress  world     economies european
#  [9,] international can           want      need      seoul     also
# [10,] country       international ’re       –         will      countries
#       Topic 7  Topic 8 Topic 9
#  [1,] people   people  development
#  [2,] american will    sustainable
#  [3,] jobs     crisis  countries
#  [4,] progress ’ve     united
#  [5,] states   world   nations
#  [6,] united   europe  summit
#  [7,] ’ve      agreed  climate
#  [8,] nations  economy leaders
#  [9,] climate  jobs    agenda
# [10,] made     global  peace

# %% [markdown]
# #### Plotting the distribution of words per topic

# %%
ap_topics <- tidy(ldaOut, matrix = "beta")
ap_top_terms <- ap_topics %>%
  group_by(topic) %>%
  top_n(n_top_words, beta) %>%
  ungroup() %>%
  arrange(topic, -beta)

# %%
options(repr.plot.width=18, repr.plot.height=15)

# %%
ap_top_terms %>%
  mutate(term = reorder_within(term, beta, topic)) %>%
  ggplot(aes(term, beta, fill = factor(topic))) +
  geom_col(show.legend = FALSE) +
  facet_wrap(~ topic, scales = "free") +
  coord_flip() +
  theme(text=element_text(size=20)) +
  scale_x_reordered()
# Out:
# plot without title

# %% [markdown]
# ***
#
# ## Topic modeling at the sentence level

# %%
text <- document_term_matrix(sentences$text)
# Out:
# Warning message in tm_map.SimpleCorpus(text, stripWhitespace):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, content_transformer(tolower)):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removeWords, stopwords("english")):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(text, removeNumbers):
# “transformation drops documents”

# %% [markdown]
# #### How many sentences do we have?

# %%
length(sentences$text)
# Out:
# [1] 646

# %% [markdown]
# #### Given the number of sentences, let's consider ~20 topics

# %%
n_topics = 20
dtm <- DocumentTermMatrix(text)
dtm <- removeSparseTerms(dtm, 0.99)

# %% [markdown]
# As we are using sentences, there might be [errors](https://stackoverflow.com/questions/37802380/error-in-lda-in-r-each-row-of-the-input-matrix-needs-to-contain-at-least-one-no) on the creation of the document-term-matrix, e.g., short sentences mostly made of stopwords. To avoid this problem, we must run the code snippet below to fix our document-term-matrix

# %%
raw.sum <- apply(dtm, 1, FUN=sum) #sum by raw each raw of the table 
sentences <- sentences[raw.sum != 0,]
dtm <- dtm[raw.sum != 0,]

# %% [markdown]
# #### Once again, we run LDA

# %%
ldaOut <- LDA(dtm, k = n_topics, control = list(alpha=0.1))

# %% [markdown]
# #### This time, we want to check which sentences belong to which topic
#
# We will use the `matrix` parameter to obtain this data

# %%
ap_documents <- tidy(ldaOut, matrix = "gamma")
head(ap_documents)
# Out:
#   document topic gamma
# 1 1        1     0.010394512
# 2 2        1     0.003078643
# 3 3        1     0.001588217
# 4 4        1     0.005800154
# 5 5        1     0.003078643
# 6 6        1     0.001588217

# %% [markdown]
# `gamma` represents how likely a sentence relates to a topic.
#
# In this example, most of the sentences are not related to topic 1 (i.e., `gamma < 0.01`).
#
# However, we notice a sentence that seems related to the topic with a high probability (i.e., `gamma > 0.6`).
#
# ***
#
# ### We can filter sentences acording to a certain threshold for gamma

# %%
sentences_topics <- ap_documents %>% 
  rowwise() %>% 
  filter(gamma > 0.6) %>%
  mutate(name= sentences$text[as.numeric(document)]) %>%
  arrange(topic) %>%
  na.omit()

# %% [markdown]
# ***
#
# #### Sample of sentences per topic
#
# ## Exercise: can you relate these sentences to our manually created codes?

# %%
sample <- sentences_topics %>%
  filter(topic == 1)

head(data.frame(sentences=sample$name), n=5)
# Out:
#   sentences
# 1 Countries with large deficits must work to reduce them, as we are doing in the United States, where we’re on track to cut our deficit in half by 2013, and where I’m prepared to make tough decisions to achieve that goal.
# 2 But our European partners have laid a foundation on which to build, and it has all the elements needed for success:  a credible firewall to prevent the crisis from spreading, strengthening European banks, charting a sustainable path for Greece, and confronting the structural issues that are at the heart of the current crisis.
# 3 We also made progress here in Cannes on our rebalancing agenda.
# 4 So, again, I want to thank President Sarkozy and our French hosts for a productive summit.
# 5 Failing to respond to this breach of this international norm would send a signal to rogue nations, authoritarian regimes, and terrorist organizations that they can develop and use weapons of mass destruction and not pay a consequence.

# %%
sample <- sentences_topics %>%
  filter(topic == 5)

head(data.frame(sentences=sample$name), n=5)
# Out:
#   sentences
# 1 And as a consequence, our economy is growing again -– even as we must do more to ensure that that growth is sustained and translates into jobs for our people.
# 2 And that's why I spoke very frankly to my G20 partners today about the prospects of the Doha Round.
# 3 And now and in the days ahead, these are the commitments that we’re going to have to meet.
# 4 Now, markets around the world as well as governments have been asking if Europe is ready to do what is necessary to hold the eurozone together.
# 5 This is an essential to promoting growth, innovation and jobs in the United States.

# %%
sample <- sentences_topics %>%
  filter(topic == 2)

head(data.frame(sentences=sample$name), n=5)
# Out:
#   sentences
# 1 We worked together to pull the global economy back from catastrophe.
# 2 In short, we succeeded in putting the global economy back on the path of recovery -- but we also know that the progress has not come nearly fast enough, especially when it comes to my highest priority, which is putting Americans back to work.
# 3 Nor have we yet achieved the balanced global growth that we need.
# 4 Put simply, we risk slipping back into the old imbalances that contributed to the economic crisis in the first place and which threaten global recovery.
# 5 So here in Seoul, the question was whether our nations could work together to keep the global economy growing.

# %% [markdown]
# ### Challenges
#
# 1. The biggest challenge with topic modeling is deciding a proper number of topics
#   1. A small number of topics will cluster together `unrelated documents`
#   1. A large number of topics will make documents per topic `too sparse`
# 1. The words in a topic might not be that insightful as `topics are derived from the data`. Sometimes, it's better to have some prior knowledge and `try to guide the creation` of topics ourselves
# 1. Defining thresholds (e.g., `gamma`) to fine tune the model and cluster documents/sentences accordingly

# %% [markdown]
# ***
#
# # Research Commons: An interdisciplinary research-driven learning environment
#
#
# ### * Literature review
# ### * Systematic Review Search  Methodology
# ### * Citation Management
# ### * Thesis Formatting
#
#
# ### * Nvivo Software Support
#
#
#
# ### * SPSS Software Support
#
# <img style="float: right;" src="figures/research_commons_logo.png">
#
#
# ### * R Group
#
#
#
# ### * Multi-Disciplinary Graduate Student Writing Group
#
# ***

# %% [markdown]
# <img style="position: relative;" src="figures/background.png">
#
# <img style="position: absolute; top: 50px; left: 200px; background: rgba(255,255,255, 0.5);" src="figures/thanks.png">

# %% [markdown]
# <center> <h1>Feedback</h1><h2>http://bit.ly/RCfeedbackwinter2018</h2> </center>

# %% [markdown]
# # References
#
# 1. [Text Mining with R](https://www.tidytextmining.com/)
# 1. [Qualitative Research in R](https://datascienceplus.com/qualitative-research-in-r/)
# 1. [An Introduction to Codes and   Coding](https://www.sagepub.com/sites/default/files/upm-binaries/24614_01_Saldana_Ch_01.pdf)
# 1. [topicmodels:  An R Package for Fitting Topic Models](https://cran.r-project.org/web/packages/topicmodels/vignettes/topicmodels.pdf)
# 1. [Text Mining for Social and Behavioral Research Using R](https://books.psychstat.org/textmining/index.html)
# 1. [Qualitative Data Science: Using RQDA to analyse interviews](https://lucidmanager.org/qualitative-data-science/)
# 1. [Sensemaking and Analytics for Organizations - A gentle introduction to topic modeling using R](https://eight2late.wordpress.com/2015/09/29/a-gentle-introduction-to-topic-modeling-using-r/)
